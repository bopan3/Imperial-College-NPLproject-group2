# %% [markdown]
# # 1.数据预处理

# %% [markdown]
# ## __1.1数据来源获取：wiki https://dumps.wikimedia.org/zhwiki/

# %% [markdown]
# ## __1.2 XML格式->文本格式：wikiExtractor

# %% [markdown]
# ## __1.3 文本格式数据繁体化为简体 (该格不需运行（耗时很长），如需运行先pip install opencc)

# %%
import os, sys
import logging
from optparse import OptionParser
from opencc import OpenCC

def zh_t2s(infile, outfile):
    '''convert the traditional Chinese of infile into the simplified Chinese of outfile'''

    # read the traditional Chinese file
    t_corpus = []
    with open(infile,'r',encoding='utf-8') as f:
        for line in f:
            line = line.replace('\n', '').replace('\t','')
            t_corpus.append(line)
    #logger.info('read traditional file finished!')

    # convert the t_Chinese to s_Chinese
    cc = OpenCC('t2s')
    s_corpus = []
    for i,line in zip(range(len(t_corpus)),t_corpus):
        #if i % 1000 == 0:
            #logger.info('convert t2s with the {}/{} line'.format(i,len(t_corpus)))
        # s_corpus.append(OpenCC.convert(line))
        s_corpus.append(cc.convert(line))
    #logger.info('convert t2s finished!')

    # write the simplified Chinese into the outfile
    with open(outfile, 'w', encoding='utf-8') as f:
        for line in s_corpus:
            f.writelines(line + '\n')
    #logger.info('write the simplified file finished!')

"""
if __name__ == '__main__':
    program = os.path.basename(sys.argv[0])
    logger = logging.getLogger(program)
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    logger.info('running ' + program + ' : convert Traditional Chinese to Simplified Chinese')

    parser = OptionParser()
    parser.add_option('-i','--input',dest='input_file',default='corpus.zhwiki.txt',help='traditional file')
    parser.add_option('-o','--output',dest='output_file',default='corpus.zhwiki.simplified.txt',help='simplified file')
    (options,args) = parser.parse_args()

    input_file = options.input_file
    output_file = options.output_file

    try:
        zh_t2s(infile=input_file,outfile=output_file)
        logger.info('Traditional Chinese to Simplified Chinese Finished')
    except Exception as err:
        logger.info(err)
"""





""" 如需重新运行 将这段代码去注释

for sub_dir_name in os.listdir('text'):
    if sub_dir_name[0]!='.':
        
        for fname in os.listdir('text/'+sub_dir_name):
            cur_file='text/'+sub_dir_name+'/'+fname
            ot_file="./after_t2s/"+str(sub_dir_name)+'_'+fname
            zh_t2s(cur_file, ot_file)
            #print(ot_file)
            #pass
            #print(fname)

#cur_file="./text/AA/wiki_00"
#ot_file="./after_t2s/after_t2s"
#zh_t2s(cur_file, ot_file)
"""

# %% [markdown]
# ## __1.4 中文分词处理 (该格不需运行（耗时很长），如需运行先pip install jiaba)

# %%
import jieba
import os, sys
import logging
def split_word(infile, outfile):
    '''do wordSplit on sentences from infile, write to outfile'''

    # read the input file
    i_corpus = []
    #print(infile)
    with open(infile,'r',encoding='utf-8') as f:
        for line in f:
            #print(line[0])
            line=line.strip()
            if len(line)!=0 and line[0]!='<' and line[0]!='※':
                line = line.replace('\n', '').replace('\t','')
                i_corpus.append(line)
    #logger.info('read traditional file finished!')

    # convert the t_Chinese to s_Chinese
    #cc = OpenCC('t2s')
    f.close()
    s_corpus = []
    for i,line in zip(range(len(i_corpus)),i_corpus):
        #if i % 1000 == 0:
            #logger.info('convert t2s with the {}/{} line'.format(i,len(t_corpus)))
        # s_corpus.append(OpenCC.convert(line))
        out_sentence=" ".join(jieba.cut(line, cut_all=False))
        s_corpus.append(out_sentence)
    #logger.info('convert t2s finished!')

    # write the simplified Chinese into the outfile
    with open(outfile, 'w', encoding='utf-8') as f:
        for line in s_corpus:
            f.writelines(line + '\n')
    #logger.info('write the simplified file finished!')
    f.close()
    
stop_for_test=1    
for file_name in os.listdir('after_t2s'):
    print("Processing the {file_num}th file... Progress:{progress}%".format(file_num=stop_for_test,progress=stop_for_test/1420*100))
    if file_name[0]!='.' and (not file_name in os.listdir('after_wordSplit')):        
            cur_file='after_t2s/'+file_name
            ot_file="./after_wordSplit/"+file_name
            #print(cur_file)
            split_word(cur_file, ot_file)
            #print(ot_file)
            #pass
            #print(fname)
    stop_for_test=stop_for_test+1
# Out:
# Processing the 1th file... Progress:0.07042253521126761%
# Processing the 2th file... Progress:0.14084507042253522%
# Processing the 3th file... Progress:0.21126760563380279%
# Processing the 4th file... Progress:0.28169014084507044%
# Processing the 5th file... Progress:0.35211267605633806%
# Processing the 6th file... Progress:0.42253521126760557%
# Processing the 7th file... Progress:0.49295774647887325%
# Processing the 8th file... Progress:0.5633802816901409%
# Processing the 9th file... Progress:0.6338028169014085%
# Processing the 10th file... Progress:0.7042253521126761%
# Processing the 11th file... Progress:0.7746478873239436%
# Processing the 12th file... Progress:0.8450704225352111%
# Processing the 13th file... Progress:0.9154929577464789%
# Processing the 14th file... Progress:0.9859154929577465%
# Processing the 15th file... Progress:1.056338028169014%
# Processing the 16th file... Progress:1.1267605633802817%
# Processing the 17th file... Progress:1.1971830985915493%
# Processing the 18th file... Progress:1.267605633802817%
# Processing the 19th file... Progress:1.3380281690140845%
# Processing the 20th file... Progress:1.4084507042253522%
# Processing the 21th file... Progress:1.4788732394366197%
# Processing the 22th file... Progress:1.5492957746478873%
# Processing the 23th file... Progress:1.6197183098591548%
# Processing the 24th file... Progress:1.6901408450704223%
# Processing the 25th file... Progress:1.7605633802816902%
# Processing the 26th file... Progress:1.8309859154929577%
# Processing the 27th file... Progress:1.9014084507042253%
# Processing the 28th file... Progress:1.971830985915493%
# Processing the 29th file... Progress:2.0422535211267605%
# Processing the 30th file... Progress:2.112676056338028%
# Processing the 31th file... Progress:2.1830985915492955%
# Processing the 32th file... Progress:2.2535211267605635%
# Processing the 33th file... Progress:2.323943661971831%
# Processing the 34th file... Progress:2.3943661971830985%
# Processing the 35th file... Progress:2.464788732394366%
# Processing the 36th file... Progress:2.535211267605634%
# Processing the 37th file... Progress:2.6056338028169015%
# Processing the 38th file... Progress:2.676056338028169%
# Processing the 39th file... Progress:2.746478873239437%
# Processing the 40th file... Progress:2.8169014084507045%
# Processing the 41th file... Progress:2.887323943661972%
# Processing the 42th file... Progress:2.9577464788732395%
# Processing the 43th file... Progress:3.028169014084507%
# Processing the 44th file... Progress:3.0985915492957745%
# Processing the 45th file... Progress:3.169014084507042%
# Processing the 46th file... Progress:3.2394366197183095%
# Processing the 47th file... Progress:3.309859154929577%
# Processing the 48th file... Progress:3.3802816901408446%
# Processing the 49th file... Progress:3.450704225352113%
# Processing the 50th file... Progress:3.5211267605633805%
# Processing the 51th file... Progress:3.591549295774648%
# Processing the 52th file... Progress:3.6619718309859155%
# Processing the 53th file... Progress:3.732394366197183%
# Processing the 54th file... Progress:3.8028169014084505%
# Processing the 55th file... Progress:3.873239436619718%
# Processing the 56th file... Progress:3.943661971830986%
# Processing the 57th file... Progress:4.014084507042254%
# Processing the 58th file... Progress:4.084507042253521%
# Processing the 59th file... Progress:4.154929577464789%
# Processing the 60th file... Progress:4.225352112676056%
# Processing the 61th file... Progress:4.295774647887324%
# Processing the 62th file... Progress:4.366197183098591%
# Processing the 63th file... Progress:4.43661971830986%
# Processing the 64th file... Progress:4.507042253521127%
# Processing the 65th file... Progress:4.577464788732395%
# Processing the 66th file... Progress:4.647887323943662%
# Processing the 67th file... Progress:4.71830985915493%
# Processing the 68th file... Progress:4.788732394366197%
# Processing the 69th file... Progress:4.859154929577465%
# Processing the 70th file... Progress:4.929577464788732%
# Processing the 71th file... Progress:5.0%
# Processing the 72th file... Progress:5.070422535211268%
# Processing the 73th file... Progress:5.140845070422535%
# Processing the 74th file... Progress:5.211267605633803%
# Processing the 75th file... Progress:5.28169014084507%
# Processing the 76th file... Progress:5.352112676056338%
# Processing the 77th file... Progress:5.422535211267605%
# Processing the 78th file... Progress:5.492957746478874%
# Processing the 79th file... Progress:5.563380281690141%
# Processing the 80th file... Progress:5.633802816901409%
# Processing the 81th file... Progress:5.704225352112676%
# Processing the 82th file... Progress:5.774647887323944%
# Processing the 83th file... Progress:5.845070422535211%
# Processing the 84th file... Progress:5.915492957746479%
# Processing the 85th file... Progress:5.985915492957746%
# Processing the 86th file... Progress:6.056338028169014%
# Processing the 87th file... Progress:6.126760563380282%
# Processing the 88th file... Progress:6.197183098591549%
# Processing the 89th file... Progress:6.267605633802817%
# Processing the 90th file... Progress:6.338028169014084%
# Processing the 91th file... Progress:6.408450704225352%
# Processing the 92th file... Progress:6.478873239436619%
# Processing the 93th file... Progress:6.549295774647887%
# Processing the 94th file... Progress:6.619718309859154%
# Processing the 95th file... Progress:6.690140845070422%
# Processing the 96th file... Progress:6.760563380281689%
# Processing the 97th file... Progress:6.830985915492958%
# Processing the 98th file... Progress:6.901408450704226%
# Processing the 99th file... Progress:6.971830985915493%
# Processing the 100th file... Progress:7.042253521126761%
# Processing the 101th file... Progress:7.112676056338028%
# Processing the 102th file... Progress:7.183098591549296%
# Processing the 103th file... Progress:7.253521126760563%
# Processing the 104th file... Progress:7.323943661971831%
# Processing the 105th file... Progress:7.394366197183098%
# Processing the 106th file... Progress:7.464788732394366%
# Processing the 107th file... Progress:7.535211267605633%
# Processing the 108th file... Progress:7.605633802816901%
# Processing the 109th file... Progress:7.676056338028168%
# Processing the 110th file... Progress:7.746478873239436%
# Processing the 111th file... Progress:7.816901408450705%
# Processing the 112th file... Progress:7.887323943661972%
# Processing the 113th file... Progress:7.95774647887324%
# Processing the 114th file... Progress:8.028169014084508%
# Processing the 115th file... Progress:8.098591549295776%
# Processing the 116th file... Progress:8.169014084507042%
# Processing the 117th file... Progress:8.23943661971831%
# Processing the 118th file... Progress:8.309859154929578%
# Processing the 119th file... Progress:8.380281690140844%
# Processing the 120th file... Progress:8.450704225352112%
# Processing the 121th file... Progress:8.52112676056338%
# Processing the 122th file... Progress:8.591549295774648%
# Processing the 123th file... Progress:8.661971830985916%
# Processing the 124th file... Progress:8.732394366197182%
# Processing the 125th file... Progress:8.80281690140845%
# Processing the 126th file... Progress:8.87323943661972%
# Processing the 127th file... Progress:8.943661971830986%
# Processing the 128th file... Progress:9.014084507042254%
# Processing the 129th file... Progress:9.084507042253522%
# Processing the 130th file... Progress:9.15492957746479%
# Processing the 131th file... Progress:9.225352112676056%
# Processing the 132th file... Progress:9.295774647887324%
# Processing the 133th file... Progress:9.366197183098592%
# Processing the 134th file... Progress:9.43661971830986%
# Processing the 135th file... Progress:9.507042253521126%
# Processing the 136th file... Progress:9.577464788732394%
# Processing the 137th file... Progress:9.647887323943662%
# Processing the 138th file... Progress:9.71830985915493%
# Processing the 139th file... Progress:9.788732394366196%
# Processing the 140th file... Progress:9.859154929577464%
# Processing the 141th file... Progress:9.929577464788734%
# Processing the 142th file... Progress:10.0%
# Processing the 143th file... Progress:10.070422535211268%
# Processing the 144th file... Progress:10.140845070422536%
# Processing the 145th file... Progress:10.211267605633804%
# Processing the 146th file... Progress:10.28169014084507%
# Processing the 147th file... Progress:10.352112676056338%
# Processing the 148th file... Progress:10.422535211267606%
# Processing the 149th file... Progress:10.492957746478874%
# Processing the 150th file... Progress:10.56338028169014%
# Processing the 151th file... Progress:10.633802816901408%
# Processing the 152th file... Progress:10.704225352112676%
# Processing the 153th file... Progress:10.774647887323944%
# Processing the 154th file... Progress:10.84507042253521%
# Processing the 155th file... Progress:10.915492957746478%
# Processing the 156th file... Progress:10.985915492957748%
# Processing the 157th file... Progress:11.056338028169014%
# Processing the 158th file... Progress:11.126760563380282%
# Processing the 159th file... Progress:11.19718309859155%
# Processing the 160th file... Progress:11.267605633802818%
# Processing the 161th file... Progress:11.338028169014084%
# Processing the 162th file... Progress:11.408450704225352%
# Processing the 163th file... Progress:11.47887323943662%
# Processing the 164th file... Progress:11.549295774647888%
# Processing the 165th file... Progress:11.619718309859154%
# Processing the 166th file... Progress:11.690140845070422%
# Processing the 167th file... Progress:11.76056338028169%
# Processing the 168th file... Progress:11.830985915492958%
# Processing the 169th file... Progress:11.901408450704224%
# Processing the 170th file... Progress:11.971830985915492%
# Processing the 171th file... Progress:12.042253521126762%
# Processing the 172th file... Progress:12.112676056338028%
# Processing the 173th file... Progress:12.183098591549296%
# Processing the 174th file... Progress:12.253521126760564%
# Processing the 175th file... Progress:12.323943661971832%
# Processing the 176th file... Progress:12.394366197183098%
# Processing the 177th file... Progress:12.464788732394366%
# Processing the 178th file... Progress:12.535211267605634%
# Processing the 179th file... Progress:12.605633802816902%
# Processing the 180th file... Progress:12.676056338028168%
# Processing the 181th file... Progress:12.746478873239436%
# Processing the 182th file... Progress:12.816901408450704%
# Processing the 183th file... Progress:12.887323943661972%
# Processing the 184th file... Progress:12.957746478873238%
# Processing the 185th file... Progress:13.028169014084506%
# Processing the 186th file... Progress:13.098591549295774%
# Processing the 187th file... Progress:13.169014084507042%
# Processing the 188th file... Progress:13.239436619718308%
# Processing the 189th file... Progress:13.309859154929576%
# Processing the 190th file... Progress:13.380281690140844%
# Processing the 191th file... Progress:13.450704225352112%
# Processing the 192th file... Progress:13.521126760563378%
# Processing the 193th file... Progress:13.59154929577465%
# Processing the 194th file... Progress:13.661971830985916%
# Processing the 195th file... Progress:13.732394366197184%
# Processing the 196th file... Progress:13.802816901408452%
# Processing the 197th file... Progress:13.87323943661972%
# Processing the 198th file... Progress:13.943661971830986%
# Processing the 199th file... Progress:14.014084507042254%
# Processing the 200th file... Progress:14.084507042253522%
# Processing the 201th file... Progress:14.15492957746479%
# Processing the 202th file... Progress:14.225352112676056%
# Processing the 203th file... Progress:14.295774647887324%
# Processing the 204th file... Progress:14.366197183098592%
# Processing the 205th file... Progress:14.43661971830986%
# Processing the 206th file... Progress:14.507042253521126%
# Processing the 207th file... Progress:14.577464788732394%
# Processing the 208th file... Progress:14.647887323943662%
# Processing the 209th file... Progress:14.71830985915493%
# Processing the 210th file... Progress:14.788732394366196%
# Processing the 211th file... Progress:14.859154929577464%
# Processing the 212th file... Progress:14.929577464788732%
# Processing the 213th file... Progress:15.0%
# Processing the 214th file... Progress:15.070422535211266%
# Processing the 215th file... Progress:15.140845070422534%
# Processing the 216th file... Progress:15.211267605633802%
# Processing the 217th file... Progress:15.28169014084507%
# Processing the 218th file... Progress:15.352112676056336%
# Processing the 219th file... Progress:15.422535211267604%
# Processing the 220th file... Progress:15.492957746478872%
# Processing the 221th file... Progress:15.56338028169014%
# Processing the 222th file... Progress:15.63380281690141%
# Processing the 223th file... Progress:15.704225352112678%
# Processing the 224th file... Progress:15.774647887323944%
# Processing the 225th file... Progress:15.845070422535212%
# Processing the 226th file... Progress:15.91549295774648%
# Processing the 227th file... Progress:15.985915492957748%
# Processing the 228th file... Progress:16.056338028169016%
# Processing the 229th file... Progress:16.126760563380284%
# Processing the 230th file... Progress:16.19718309859155%
# Processing the 231th file... Progress:16.267605633802816%
# Processing the 232th file... Progress:16.338028169014084%
# Processing the 233th file... Progress:16.408450704225352%
# Processing the 234th file... Progress:16.47887323943662%
# Processing the 235th file... Progress:16.549295774647888%
# Processing the 236th file... Progress:16.619718309859156%
# Processing the 237th file... Progress:16.690140845070424%
# Processing the 238th file... Progress:16.76056338028169%
# Processing the 239th file... Progress:16.830985915492956%
# Processing the 240th file... Progress:16.901408450704224%
# Processing the 241th file... Progress:16.971830985915492%
# Processing the 242th file... Progress:17.04225352112676%
# Processing the 243th file... Progress:17.112676056338028%
# Processing the 244th file... Progress:17.183098591549296%
# Processing the 245th file... Progress:17.253521126760564%
# Processing the 246th file... Progress:17.323943661971832%
# Processing the 247th file... Progress:17.394366197183096%
# Processing the 248th file... Progress:17.464788732394364%
# Processing the 249th file... Progress:17.535211267605632%
# Processing the 250th file... Progress:17.6056338028169%
# Processing the 251th file... Progress:17.676056338028168%
# Processing the 252th file... Progress:17.74647887323944%
# Processing the 253th file... Progress:17.816901408450704%
# Processing the 254th file... Progress:17.887323943661972%
# Processing the 255th file... Progress:17.95774647887324%
# Processing the 256th file... Progress:18.028169014084508%
# Processing the 257th file... Progress:18.098591549295776%
# Processing the 258th file... Progress:18.169014084507044%
# Processing the 259th file... Progress:18.23943661971831%
# Processing the 260th file... Progress:18.30985915492958%
# Processing the 261th file... Progress:18.380281690140844%
# Processing the 262th file... Progress:18.450704225352112%
# Processing the 263th file... Progress:18.52112676056338%
# Processing the 264th file... Progress:18.591549295774648%
# Processing the 265th file... Progress:18.661971830985916%
# Processing the 266th file... Progress:18.732394366197184%
# Processing the 267th file... Progress:18.802816901408452%
# Processing the 268th file... Progress:18.87323943661972%
# Processing the 269th file... Progress:18.943661971830984%
# Processing the 270th file... Progress:19.014084507042252%
# Processing the 271th file... Progress:19.08450704225352%
# Processing the 272th file... Progress:19.154929577464788%
# Processing the 273th file... Progress:19.225352112676056%
# Processing the 274th file... Progress:19.295774647887324%
# Processing the 275th file... Progress:19.366197183098592%
# Processing the 276th file... Progress:19.43661971830986%
# Processing the 277th file... Progress:19.507042253521124%
# Processing the 278th file... Progress:19.577464788732392%
# Processing the 279th file... Progress:19.64788732394366%
# Processing the 280th file... Progress:19.718309859154928%
# Processing the 281th file... Progress:19.788732394366196%
# Processing the 282th file... Progress:19.859154929577468%
# Processing the 283th file... Progress:19.929577464788732%
# Processing the 284th file... Progress:20.0%
# Processing the 285th file... Progress:20.070422535211268%
# Processing the 286th file... Progress:20.140845070422536%
# Processing the 287th file... Progress:20.211267605633804%
# Processing the 288th file... Progress:20.281690140845072%
# Processing the 289th file... Progress:20.35211267605634%
# Processing the 290th file... Progress:20.422535211267608%
# Processing the 291th file... Progress:20.492957746478872%
# Processing the 292th file... Progress:20.56338028169014%
# Processing the 293th file... Progress:20.633802816901408%
# Processing the 294th file... Progress:20.704225352112676%
# Processing the 295th file... Progress:20.774647887323944%
# Processing the 296th file... Progress:20.845070422535212%
# Processing the 297th file... Progress:20.91549295774648%
# Processing the 298th file... Progress:20.985915492957748%
# Processing the 299th file... Progress:21.056338028169012%
# Processing the 300th file... Progress:21.12676056338028%
# Processing the 301th file... Progress:21.197183098591548%
# Processing the 302th file... Progress:21.267605633802816%
# Processing the 303th file... Progress:21.338028169014084%
# Processing the 304th file... Progress:21.408450704225352%
# Processing the 305th file... Progress:21.47887323943662%
# Processing the 306th file... Progress:21.549295774647888%
# Processing the 307th file... Progress:21.619718309859152%
# Processing the 308th file... Progress:21.69014084507042%
# Processing the 309th file... Progress:21.76056338028169%
# Processing the 310th file... Progress:21.830985915492956%
# Processing the 311th file... Progress:21.901408450704228%
# Processing the 312th file... Progress:21.971830985915496%
# Processing the 313th file... Progress:22.04225352112676%
# Processing the 314th file... Progress:22.112676056338028%
# Processing the 315th file... Progress:22.183098591549296%
# Processing the 316th file... Progress:22.253521126760564%
# Processing the 317th file... Progress:22.323943661971832%
# Processing the 318th file... Progress:22.3943661971831%
# Processing the 319th file... Progress:22.464788732394368%
# Processing the 320th file... Progress:22.535211267605636%
# Processing the 321th file... Progress:22.6056338028169%
# Processing the 322th file... Progress:22.676056338028168%
# Processing the 323th file... Progress:22.746478873239436%
# Processing the 324th file... Progress:22.816901408450704%
# Processing the 325th file... Progress:22.887323943661972%
# Processing the 326th file... Progress:22.95774647887324%
# Processing the 327th file... Progress:23.028169014084508%
# Processing the 328th file... Progress:23.098591549295776%
# Processing the 329th file... Progress:23.16901408450704%
# Processing the 330th file... Progress:23.239436619718308%
# Processing the 331th file... Progress:23.309859154929576%
# Processing the 332th file... Progress:23.380281690140844%
# Processing the 333th file... Progress:23.450704225352112%
# Processing the 334th file... Progress:23.52112676056338%
# Processing the 335th file... Progress:23.591549295774648%
# Processing the 336th file... Progress:23.661971830985916%
# Processing the 337th file... Progress:23.73239436619718%
# Processing the 338th file... Progress:23.80281690140845%
# Processing the 339th file... Progress:23.873239436619716%
# Processing the 340th file... Progress:23.943661971830984%
# Processing the 341th file... Progress:24.014084507042256%
# Processing the 342th file... Progress:24.084507042253524%
# Processing the 343th file... Progress:24.15492957746479%
# Processing the 344th file... Progress:24.225352112676056%
# Processing the 345th file... Progress:24.295774647887324%
# Processing the 346th file... Progress:24.366197183098592%
# Processing the 347th file... Progress:24.43661971830986%
# Processing the 348th file... Progress:24.507042253521128%
# Processing the 349th file... Progress:24.577464788732396%
# Processing the 350th file... Progress:24.647887323943664%
# Processing the 351th file... Progress:24.718309859154928%
# Processing the 352th file... Progress:24.788732394366196%
# Processing the 353th file... Progress:24.859154929577464%
# Processing the 354th file... Progress:24.929577464788732%
# Processing the 355th file... Progress:25.0%
# Processing the 356th file... Progress:25.070422535211268%
# Processing the 357th file... Progress:25.140845070422536%
# Processing the 358th file... Progress:25.211267605633804%
# Processing the 359th file... Progress:25.281690140845072%
# Processing the 360th file... Progress:25.352112676056336%
# Processing the 361th file... Progress:25.422535211267604%
# Processing the 362th file... Progress:25.492957746478872%
# Processing the 363th file... Progress:25.56338028169014%
# Processing the 364th file... Progress:25.633802816901408%
# Processing the 365th file... Progress:25.704225352112676%
# Processing the 366th file... Progress:25.774647887323944%
# Processing the 367th file... Progress:25.84507042253521%
# Processing the 368th file... Progress:25.915492957746476%
# Processing the 369th file... Progress:25.985915492957744%
# Processing the 370th file... Progress:26.056338028169012%
# Processing the 371th file... Progress:26.12676056338028%
# Processing the 372th file... Progress:26.197183098591548%
# Processing the 373th file... Progress:26.267605633802816%
# Processing the 374th file... Progress:26.338028169014084%
# Processing the 375th file... Progress:26.408450704225352%
# Processing the 376th file... Progress:26.478873239436616%
# Processing the 377th file... Progress:26.549295774647884%
# Processing the 378th file... Progress:26.619718309859152%
# Processing the 379th file... Progress:26.69014084507042%
# Processing the 380th file... Progress:26.76056338028169%
# Processing the 381th file... Progress:26.830985915492956%
# Processing the 382th file... Progress:26.901408450704224%
# Processing the 383th file... Progress:26.97183098591549%
# Processing the 384th file... Progress:27.042253521126757%
# Processing the 385th file... Progress:27.11267605633803%
# Processing the 386th file... Progress:27.1830985915493%
# Processing the 387th file... Progress:27.253521126760567%
# Processing the 388th file... Progress:27.323943661971832%
# Processing the 389th file... Progress:27.3943661971831%
# Processing the 390th file... Progress:27.464788732394368%
# Processing the 391th file... Progress:27.535211267605636%
# Processing the 392th file... Progress:27.605633802816904%
# Processing the 393th file... Progress:27.67605633802817%
# Processing the 394th file... Progress:27.74647887323944%
# Processing the 395th file... Progress:27.816901408450708%
# Processing the 396th file... Progress:27.887323943661972%
# Processing the 397th file... Progress:27.95774647887324%
# Processing the 398th file... Progress:28.028169014084508%
# Processing the 399th file... Progress:28.098591549295776%
# Processing the 400th file... Progress:28.169014084507044%
# Processing the 401th file... Progress:28.23943661971831%
# Processing the 402th file... Progress:28.30985915492958%
# Processing the 403th file... Progress:28.380281690140848%
# Processing the 404th file... Progress:28.450704225352112%
# Processing the 405th file... Progress:28.52112676056338%
# Processing the 406th file... Progress:28.591549295774648%
# Processing the 407th file... Progress:28.661971830985916%
# Processing the 408th file... Progress:28.732394366197184%
# Processing the 409th file... Progress:28.802816901408452%
# Processing the 410th file... Progress:28.87323943661972%
# Processing the 411th file... Progress:28.943661971830988%
# Processing the 412th file... Progress:29.014084507042252%
# Processing the 413th file... Progress:29.08450704225352%
# Processing the 414th file... Progress:29.154929577464788%
# Processing the 415th file... Progress:29.225352112676056%
# Processing the 416th file... Progress:29.295774647887324%
# Processing the 417th file... Progress:29.366197183098592%
# Processing the 418th file... Progress:29.43661971830986%
# Processing the 419th file... Progress:29.507042253521128%
# Processing the 420th file... Progress:29.577464788732392%
# Processing the 421th file... Progress:29.64788732394366%
# Processing the 422th file... Progress:29.718309859154928%
# Processing the 423th file... Progress:29.788732394366196%
# Processing the 424th file... Progress:29.859154929577464%
# Processing the 425th file... Progress:29.929577464788732%
# Processing the 426th file... Progress:30.0%
# Processing the 427th file... Progress:30.070422535211268%
# Processing the 428th file... Progress:30.140845070422532%
# Processing the 429th file... Progress:30.2112676056338%
# Processing the 430th file... Progress:30.28169014084507%
# Processing the 431th file... Progress:30.352112676056336%
# Processing the 432th file... Progress:30.422535211267604%
# Processing the 433th file... Progress:30.492957746478872%
# Processing the 434th file... Progress:30.56338028169014%
# Processing the 435th file... Progress:30.633802816901408%
# Processing the 436th file... Progress:30.704225352112672%
# Processing the 437th file... Progress:30.77464788732394%
# Processing the 438th file... Progress:30.84507042253521%
# Processing the 439th file... Progress:30.915492957746476%
# Processing the 440th file... Progress:30.985915492957744%
# Processing the 441th file... Progress:31.056338028169012%
# Processing the 442th file... Progress:31.12676056338028%
# Processing the 443th file... Progress:31.197183098591548%
# Processing the 444th file... Progress:31.26760563380282%
# Processing the 445th file... Progress:31.338028169014088%
# Processing the 446th file... Progress:31.408450704225356%
# Processing the 447th file... Progress:31.478873239436624%
# Processing the 448th file... Progress:31.549295774647888%
# Processing the 449th file... Progress:31.619718309859156%
# Processing the 450th file... Progress:31.690140845070424%
# Processing the 451th file... Progress:31.760563380281692%
# Processing the 452th file... Progress:31.83098591549296%
# Processing the 453th file... Progress:31.901408450704228%
# Processing the 454th file... Progress:31.971830985915496%
# Processing the 455th file... Progress:32.04225352112676%
# Processing the 456th file... Progress:32.11267605633803%
# Processing the 457th file... Progress:32.183098591549296%
# Processing the 458th file... Progress:32.25352112676057%
# Processing the 459th file... Progress:32.32394366197183%
# Processing the 460th file... Progress:32.3943661971831%
# Processing the 461th file... Progress:32.46478873239437%
# Processing the 462th file... Progress:32.53521126760563%
# Processing the 463th file... Progress:32.605633802816904%
# Processing the 464th file... Progress:32.67605633802817%
# Processing the 465th file... Progress:32.74647887323944%
# Processing the 466th file... Progress:32.816901408450704%
# Processing the 467th file... Progress:32.887323943661976%
# Processing the 468th file... Progress:32.95774647887324%
# Processing the 469th file... Progress:33.028169014084504%
# Processing the 470th file... Progress:33.098591549295776%
# Processing the 471th file... Progress:33.16901408450704%
# Processing the 472th file... Progress:33.23943661971831%
# Processing the 473th file... Progress:33.309859154929576%
# Processing the 474th file... Progress:33.38028169014085%
# Processing the 475th file... Progress:33.45070422535211%
# Processing the 476th file... Progress:33.52112676056338%
# Processing the 477th file... Progress:33.59154929577465%
# Processing the 478th file... Progress:33.66197183098591%
# Processing the 479th file... Progress:33.732394366197184%
# Processing the 480th file... Progress:33.80281690140845%
# Processing the 481th file... Progress:33.87323943661972%
# Processing the 482th file... Progress:33.943661971830984%
# Processing the 483th file... Progress:34.014084507042256%
# Processing the 484th file... Progress:34.08450704225352%
# Processing the 485th file... Progress:34.154929577464785%
# Processing the 486th file... Progress:34.225352112676056%
# Processing the 487th file... Progress:34.29577464788732%
# Processing the 488th file... Progress:34.36619718309859%
# Processing the 489th file... Progress:34.436619718309856%
# Processing the 490th file... Progress:34.50704225352113%
# Processing the 491th file... Progress:34.57746478873239%
# Processing the 492th file... Progress:34.647887323943664%
# Processing the 493th file... Progress:34.71830985915493%
# Processing the 494th file... Progress:34.78873239436619%
# Processing the 495th file... Progress:34.859154929577464%
# Processing the 496th file... Progress:34.92957746478873%
# Processing the 497th file... Progress:35.0%
# Processing the 498th file... Progress:35.070422535211264%
# Processing the 499th file... Progress:35.140845070422536%
# Processing the 500th file... Progress:35.2112676056338%
# Processing the 501th file... Progress:35.281690140845065%
# Processing the 502th file... Progress:35.352112676056336%
# Processing the 503th file... Progress:35.42253521126761%
# Processing the 504th file... Progress:35.49295774647888%
# Processing the 505th file... Progress:35.563380281690144%
# Processing the 506th file... Progress:35.63380281690141%
# Processing the 507th file... Progress:35.70422535211268%
# Processing the 508th file... Progress:35.774647887323944%
# Processing the 509th file... Progress:35.845070422535215%
# Processing the 510th file... Progress:35.91549295774648%
# Processing the 511th file... Progress:35.98591549295775%
# Processing the 512th file... Progress:36.056338028169016%
# Processing the 513th file... Progress:36.12676056338028%
# Processing the 514th file... Progress:36.19718309859155%
# Processing the 515th file... Progress:36.267605633802816%
# Processing the 516th file... Progress:36.33802816901409%
# Processing the 517th file... Progress:36.40845070422535%
# Processing the 518th file... Progress:36.47887323943662%
# Processing the 519th file... Progress:36.54929577464789%
# Processing the 520th file... Progress:36.61971830985916%
# Processing the 521th file... Progress:36.690140845070424%
# Processing the 522th file... Progress:36.76056338028169%
# Processing the 523th file... Progress:36.83098591549296%
# Processing the 524th file... Progress:36.901408450704224%
# Processing the 525th file... Progress:36.971830985915496%
# Processing the 526th file... Progress:37.04225352112676%
# Processing the 527th file... Progress:37.11267605633803%
# Processing the 528th file... Progress:37.183098591549296%
# Processing the 529th file... Progress:37.25352112676056%
# Processing the 530th file... Progress:37.32394366197183%
# Processing the 531th file... Progress:37.394366197183096%
# Processing the 532th file... Progress:37.46478873239437%
# Processing the 533th file... Progress:37.53521126760563%
# Processing the 534th file... Progress:37.605633802816904%
# Processing the 535th file... Progress:37.67605633802817%
# Processing the 536th file... Progress:37.74647887323944%
# Processing the 537th file... Progress:37.816901408450704%
# Processing the 538th file... Progress:37.88732394366197%
# Processing the 539th file... Progress:37.95774647887324%
# Processing the 540th file... Progress:38.028169014084504%
# Processing the 541th file... Progress:38.098591549295776%
# Processing the 542th file... Progress:38.16901408450704%
# Processing the 543th file... Progress:38.23943661971831%
# Processing the 544th file... Progress:38.309859154929576%
# Processing the 545th file... Progress:38.38028169014084%
# Processing the 546th file... Progress:38.45070422535211%
# Processing the 547th file... Progress:38.52112676056338%
# Processing the 548th file... Progress:38.59154929577465%
# Processing the 549th file... Progress:38.66197183098591%
# Processing the 550th file... Progress:38.732394366197184%
# Processing the 551th file... Progress:38.80281690140845%
# Processing the 552th file... Progress:38.87323943661972%
# Processing the 553th file... Progress:38.943661971830984%
# Processing the 554th file... Progress:39.01408450704225%
# Processing the 555th file... Progress:39.08450704225352%
# Processing the 556th file... Progress:39.154929577464785%
# Processing the 557th file... Progress:39.225352112676056%
# Processing the 558th file... Progress:39.29577464788732%
# Processing the 559th file... Progress:39.36619718309859%
# Processing the 560th file... Progress:39.436619718309856%
# Processing the 561th file... Progress:39.50704225352112%
# Processing the 562th file... Progress:39.57746478873239%
# Processing the 563th file... Progress:39.647887323943664%
# Processing the 564th file... Progress:39.718309859154935%
# Processing the 565th file... Progress:39.7887323943662%
# Processing the 566th file... Progress:39.859154929577464%
# Processing the 567th file... Progress:39.929577464788736%
# Processing the 568th file... Progress:40.0%
# Processing the 569th file... Progress:40.07042253521127%
# Processing the 570th file... Progress:40.140845070422536%
# Processing the 571th file... Progress:40.21126760563381%
# Processing the 572th file... Progress:40.28169014084507%
# Processing the 573th file... Progress:40.352112676056336%
# Processing the 574th file... Progress:40.42253521126761%
# Processing the 575th file... Progress:40.49295774647887%
# Processing the 576th file... Progress:40.563380281690144%
# Processing the 577th file... Progress:40.63380281690141%
# Processing the 578th file... Progress:40.70422535211268%
# Processing the 579th file... Progress:40.774647887323944%
# Processing the 580th file... Progress:40.845070422535215%
# Processing the 581th file... Progress:40.91549295774648%
# Processing the 582th file... Progress:40.985915492957744%
# Processing the 583th file... Progress:41.056338028169016%
# Processing the 584th file... Progress:41.12676056338028%
# Processing the 585th file... Progress:41.19718309859155%
# Processing the 586th file... Progress:41.267605633802816%
# Processing the 587th file... Progress:41.33802816901409%
# Processing the 588th file... Progress:41.40845070422535%
# Processing the 589th file... Progress:41.47887323943662%
# Processing the 590th file... Progress:41.54929577464789%
# Processing the 591th file... Progress:41.61971830985915%
# Processing the 592th file... Progress:41.690140845070424%
# Processing the 593th file... Progress:41.76056338028169%
# Processing the 594th file... Progress:41.83098591549296%
# Processing the 595th file... Progress:41.901408450704224%
# Processing the 596th file... Progress:41.971830985915496%
# Processing the 597th file... Progress:42.04225352112676%
# Processing the 598th file... Progress:42.112676056338024%
# Processing the 599th file... Progress:42.183098591549296%
# Processing the 600th file... Progress:42.25352112676056%
# Processing the 601th file... Progress:42.32394366197183%
# Processing the 602th file... Progress:42.394366197183096%
# Processing the 603th file... Progress:42.46478873239437%
# Processing the 604th file... Progress:42.53521126760563%
# Processing the 605th file... Progress:42.6056338028169%
# Processing the 606th file... Progress:42.67605633802817%
# Processing the 607th file... Progress:42.74647887323943%
# Processing the 608th file... Progress:42.816901408450704%
# Processing the 609th file... Progress:42.88732394366197%
# Processing the 610th file... Progress:42.95774647887324%
# Processing the 611th file... Progress:43.028169014084504%
# Processing the 612th file... Progress:43.098591549295776%
# Processing the 613th file... Progress:43.16901408450704%
# Processing the 614th file... Progress:43.239436619718305%
# Processing the 615th file... Progress:43.309859154929576%
# Processing the 616th file... Progress:43.38028169014084%
# Processing the 617th file... Progress:43.45070422535211%
# Processing the 618th file... Progress:43.52112676056338%
# Processing the 619th file... Progress:43.59154929577465%
# Processing the 620th file... Progress:43.66197183098591%
# Processing the 621th file... Progress:43.732394366197184%
# Processing the 622th file... Progress:43.802816901408455%
# Processing the 623th file... Progress:43.87323943661972%
# Processing the 624th file... Progress:43.94366197183099%
# Processing the 625th file... Progress:44.014084507042256%
# Processing the 626th file... Progress:44.08450704225352%
# Processing the 627th file... Progress:44.15492957746479%
# Processing the 628th file... Progress:44.225352112676056%
# Processing the 629th file... Progress:44.29577464788733%
# Processing the 630th file... Progress:44.36619718309859%
# Processing the 631th file... Progress:44.43661971830986%
# Processing the 632th file... Progress:44.50704225352113%
# Processing the 633th file... Progress:44.5774647887324%
# Processing the 634th file... Progress:44.647887323943664%
# Processing the 635th file... Progress:44.71830985915493%
# Processing the 636th file... Progress:44.7887323943662%
# Processing the 637th file... Progress:44.859154929577464%
# Processing the 638th file... Progress:44.929577464788736%
# Processing the 639th file... Progress:45.0%
# Processing the 640th file... Progress:45.07042253521127%
# Processing the 641th file... Progress:45.140845070422536%
# Processing the 642th file... Progress:45.2112676056338%
# Processing the 643th file... Progress:45.28169014084507%
# Processing the 644th file... Progress:45.352112676056336%
# Processing the 645th file... Progress:45.42253521126761%
# Processing the 646th file... Progress:45.49295774647887%
# Processing the 647th file... Progress:45.563380281690144%
# Processing the 648th file... Progress:45.63380281690141%
# Processing the 649th file... Progress:45.70422535211268%
# Processing the 650th file... Progress:45.774647887323944%
# Processing the 651th file... Progress:45.84507042253521%
# Processing the 652th file... Progress:45.91549295774648%
# Processing the 653th file... Progress:45.985915492957744%
# Processing the 654th file... Progress:46.056338028169016%
# Processing the 655th file... Progress:46.12676056338028%
# Processing the 656th file... Progress:46.19718309859155%
# Processing the 657th file... Progress:46.267605633802816%
# Processing the 658th file... Progress:46.33802816901408%
# Processing the 659th file... Progress:46.40845070422535%
# Processing the 660th file... Progress:46.478873239436616%
# Processing the 661th file... Progress:46.54929577464789%
# Processing the 662th file... Progress:46.61971830985915%
# Processing the 663th file... Progress:46.690140845070424%
# Processing the 664th file... Progress:46.76056338028169%
# Processing the 665th file... Progress:46.83098591549296%
# Processing the 666th file... Progress:46.901408450704224%
# Processing the 667th file... Progress:46.97183098591549%
# Processing the 668th file... Progress:47.04225352112676%
# Processing the 669th file... Progress:47.112676056338024%
# Processing the 670th file... Progress:47.183098591549296%
# Processing the 671th file... Progress:47.25352112676056%
# Processing the 672th file... Progress:47.32394366197183%
# Processing the 673th file... Progress:47.394366197183096%
# Processing the 674th file... Progress:47.46478873239436%
# Processing the 675th file... Progress:47.53521126760563%
# Processing the 676th file... Progress:47.6056338028169%
# Processing the 677th file... Progress:47.67605633802817%
# Processing the 678th file... Progress:47.74647887323943%
# Processing the 679th file... Progress:47.816901408450704%
# Processing the 680th file... Progress:47.88732394366197%
# Processing the 681th file... Progress:47.95774647887324%
# Processing the 682th file... Progress:48.02816901408451%
# Processing the 683th file... Progress:48.098591549295776%
# Processing the 684th file... Progress:48.16901408450705%
# Processing the 685th file... Progress:48.23943661971831%
# Processing the 686th file... Progress:48.30985915492958%
# Processing the 687th file... Progress:48.38028169014085%
# Processing the 688th file... Progress:48.45070422535211%
# Processing the 689th file... Progress:48.521126760563384%
# Processing the 690th file... Progress:48.59154929577465%
# Processing the 691th file... Progress:48.66197183098592%
# Processing the 692th file... Progress:48.732394366197184%
# Processing the 693th file... Progress:48.802816901408455%
# Processing the 694th file... Progress:48.87323943661972%
# Processing the 695th file... Progress:48.943661971830984%
# Processing the 696th file... Progress:49.014084507042256%
# Processing the 697th file... Progress:49.08450704225352%
# Processing the 698th file... Progress:49.15492957746479%
# Processing the 699th file... Progress:49.225352112676056%
# Processing the 700th file... Progress:49.29577464788733%
# Processing the 701th file... Progress:49.36619718309859%
# Processing the 702th file... Progress:49.436619718309856%
# Processing the 703th file... Progress:49.50704225352113%
# Processing the 704th file... Progress:49.57746478873239%
# Processing the 705th file... Progress:49.647887323943664%
# Processing the 706th file... Progress:49.71830985915493%
# Processing the 707th file... Progress:49.7887323943662%
# Processing the 708th file... Progress:49.859154929577464%
# Processing the 709th file... Progress:49.929577464788736%
# Processing the 710th file... Progress:50.0%
# Processing the 711th file... Progress:50.070422535211264%
# Processing the 712th file... Progress:50.140845070422536%
# Processing the 713th file... Progress:50.2112676056338%
# Processing the 714th file... Progress:50.28169014084507%
# Processing the 715th file... Progress:50.352112676056336%
# Processing the 716th file... Progress:50.42253521126761%
# Processing the 717th file... Progress:50.49295774647887%
# Processing the 718th file... Progress:50.563380281690144%
# Processing the 719th file... Progress:50.63380281690141%
# Processing the 720th file... Progress:50.70422535211267%
# Processing the 721th file... Progress:50.774647887323944%
# Processing the 722th file... Progress:50.84507042253521%
# Processing the 723th file... Progress:50.91549295774648%
# Processing the 724th file... Progress:50.985915492957744%
# Processing the 725th file... Progress:51.056338028169016%
# Processing the 726th file... Progress:51.12676056338028%
# Processing the 727th file... Progress:51.197183098591545%
# Processing the 728th file... Progress:51.267605633802816%
# Processing the 729th file... Progress:51.33802816901408%
# Processing the 730th file... Progress:51.40845070422535%
# Processing the 731th file... Progress:51.478873239436616%
# Processing the 732th file... Progress:51.54929577464789%
# Processing the 733th file... Progress:51.61971830985915%
# Processing the 734th file... Progress:51.69014084507042%
# Processing the 735th file... Progress:51.76056338028169%
# Processing the 736th file... Progress:51.83098591549295%
# Processing the 737th file... Progress:51.901408450704224%
# Processing the 738th file... Progress:51.97183098591549%
# Processing the 739th file... Progress:52.04225352112676%
# Processing the 740th file... Progress:52.112676056338024%
# Processing the 741th file... Progress:52.183098591549296%
# Processing the 742th file... Progress:52.25352112676056%
# Processing the 743th file... Progress:52.323943661971825%
# Processing the 744th file... Progress:52.394366197183096%
# Processing the 745th file... Progress:52.46478873239436%
# Processing the 746th file... Progress:52.53521126760563%
# Processing the 747th file... Progress:52.6056338028169%
# Processing the 748th file... Progress:52.67605633802817%
# Processing the 749th file... Progress:52.74647887323943%
# Processing the 750th file... Progress:52.816901408450704%
# Processing the 751th file... Progress:52.88732394366197%
# Processing the 752th file... Progress:52.95774647887323%
# Processing the 753th file... Progress:53.028169014084504%
# Processing the 754th file... Progress:53.09859154929577%
# Processing the 755th file... Progress:53.16901408450704%
# Processing the 756th file... Progress:53.239436619718305%
# Processing the 757th file... Progress:53.309859154929576%
# Processing the 758th file... Progress:53.38028169014084%
# Processing the 759th file... Progress:53.450704225352105%
# Processing the 760th file... Progress:53.52112676056338%
# Processing the 761th file... Progress:53.59154929577464%
# Processing the 762th file... Progress:53.66197183098591%
# Processing the 763th file... Progress:53.73239436619718%
# Processing the 764th file... Progress:53.80281690140845%
# Processing the 765th file... Progress:53.87323943661971%
# Processing the 766th file... Progress:53.94366197183098%
# Processing the 767th file... Progress:54.01408450704225%
# Processing the 768th file... Progress:54.08450704225351%
# Processing the 769th file... Progress:54.154929577464785%
# Processing the 770th file... Progress:54.22535211267606%
# Processing the 771th file... Progress:54.29577464788733%
# Processing the 772th file... Progress:54.3661971830986%
# Processing the 773th file... Progress:54.43661971830986%
# Processing the 774th file... Progress:54.507042253521135%
# Processing the 775th file... Progress:54.5774647887324%
# Processing the 776th file... Progress:54.647887323943664%
# Processing the 777th file... Progress:54.718309859154935%
# Processing the 778th file... Progress:54.7887323943662%
# Processing the 779th file... Progress:54.85915492957747%
# Processing the 780th file... Progress:54.929577464788736%
# Processing the 781th file... Progress:55.00000000000001%
# Processing the 782th file... Progress:55.07042253521127%
# Processing the 783th file... Progress:55.14084507042254%
# Processing the 784th file... Progress:55.21126760563381%
# Processing the 785th file... Progress:55.28169014084507%
# Processing the 786th file... Progress:55.35211267605634%
# Processing the 787th file... Progress:55.42253521126761%
# Processing the 788th file... Progress:55.49295774647888%
# Processing the 789th file... Progress:55.563380281690144%
# Processing the 790th file... Progress:55.633802816901415%
# Processing the 791th file... Progress:55.70422535211268%
# Processing the 792th file... Progress:55.774647887323944%
# Processing the 793th file... Progress:55.845070422535215%
# Processing the 794th file... Progress:55.91549295774648%
# Processing the 795th file... Progress:55.98591549295775%
# Processing the 796th file... Progress:56.056338028169016%
# Processing the 797th file... Progress:56.12676056338029%
# Processing the 798th file... Progress:56.19718309859155%
# Processing the 799th file... Progress:56.267605633802816%
# Processing the 800th file... Progress:56.33802816901409%
# Processing the 801th file... Progress:56.40845070422535%
# Processing the 802th file... Progress:56.47887323943662%
# Processing the 803th file... Progress:56.54929577464789%
# Processing the 804th file... Progress:56.61971830985916%
# Processing the 805th file... Progress:56.690140845070424%
# Processing the 806th file... Progress:56.760563380281695%
# Processing the 807th file... Progress:56.83098591549296%
# Processing the 808th file... Progress:56.901408450704224%
# Processing the 809th file... Progress:56.971830985915496%
# Processing the 810th file... Progress:57.04225352112676%
# Processing the 811th file... Progress:57.11267605633803%
# Processing the 812th file... Progress:57.183098591549296%
# Processing the 813th file... Progress:57.25352112676057%
# Processing the 814th file... Progress:57.32394366197183%
# Processing the 815th file... Progress:57.3943661971831%
# Processing the 816th file... Progress:57.46478873239437%
# Processing the 817th file... Progress:57.53521126760563%
# Processing the 818th file... Progress:57.605633802816904%
# Processing the 819th file... Progress:57.67605633802817%
# Processing the 820th file... Progress:57.74647887323944%
# Processing the 821th file... Progress:57.816901408450704%
# Processing the 822th file... Progress:57.887323943661976%
# Processing the 823th file... Progress:57.95774647887324%
# Processing the 824th file... Progress:58.028169014084504%
# Processing the 825th file... Progress:58.098591549295776%
# Processing the 826th file... Progress:58.16901408450704%
# Processing the 827th file... Progress:58.23943661971831%
# Processing the 828th file... Progress:58.309859154929576%
# Processing the 829th file... Progress:58.38028169014085%
# Processing the 830th file... Progress:58.45070422535211%
# Processing the 831th file... Progress:58.52112676056338%
# Processing the 832th file... Progress:58.59154929577465%
# Processing the 833th file... Progress:58.66197183098591%
# Processing the 834th file... Progress:58.732394366197184%
# Processing the 835th file... Progress:58.80281690140845%
# Processing the 836th file... Progress:58.87323943661972%
# Processing the 837th file... Progress:58.943661971830984%
# Processing the 838th file... Progress:59.014084507042256%
# Processing the 839th file... Progress:59.08450704225352%
# ...
# Processing the 1145th file... Progress:80.63380281690141%
# Processing the 1146th file... Progress:80.70422535211267%
# Processing the 1147th file... Progress:80.77464788732395%
# Processing the 1148th file... Progress:80.84507042253522%
# Processing the 1149th file... Progress:80.91549295774648%
# Processing the 1150th file... Progress:80.98591549295774%
# Processing the 1151th file... Progress:81.05633802816902%
# Processing the 1152th file... Progress:81.12676056338029%
# Processing the 1153th file... Progress:81.19718309859155%
# Processing the 1154th file... Progress:81.26760563380282%
# Processing the 1155th file... Progress:81.33802816901408%
# Processing the 1156th file... Progress:81.40845070422536%
# Processing the 1157th file... Progress:81.47887323943662%
# Processing the 1158th file... Progress:81.54929577464789%
# Processing the 1159th file... Progress:81.61971830985915%
# Processing the 1160th file... Progress:81.69014084507043%
# Processing the 1161th file... Progress:81.7605633802817%
# Processing the 1162th file... Progress:81.83098591549296%
# Processing the 1163th file... Progress:81.90140845070422%
# Processing the 1164th file... Progress:81.97183098591549%
# Processing the 1165th file... Progress:82.04225352112677%
# Processing the 1166th file... Progress:82.11267605633803%
# Processing the 1167th file... Progress:82.1830985915493%
# Processing the 1168th file... Progress:82.25352112676056%
# Processing the 1169th file... Progress:82.32394366197184%
# Processing the 1170th file... Progress:82.3943661971831%
# Processing the 1171th file... Progress:82.46478873239437%
# Processing the 1172th file... Progress:82.53521126760563%
# Processing the 1173th file... Progress:82.6056338028169%
# Processing the 1174th file... Progress:82.67605633802818%
# Processing the 1175th file... Progress:82.74647887323944%
# Processing the 1176th file... Progress:82.8169014084507%
# Processing the 1177th file... Progress:82.88732394366197%
# Processing the 1178th file... Progress:82.95774647887325%
# Processing the 1179th file... Progress:83.02816901408451%
# Processing the 1180th file... Progress:83.09859154929578%
# Processing the 1181th file... Progress:83.16901408450704%
# Processing the 1182th file... Progress:83.2394366197183%
# Processing the 1183th file... Progress:83.30985915492958%
# Processing the 1184th file... Progress:83.38028169014085%
# Processing the 1185th file... Progress:83.45070422535211%
# Processing the 1186th file... Progress:83.52112676056338%
# Processing the 1187th file... Progress:83.59154929577464%
# Processing the 1188th file... Progress:83.66197183098592%
# Processing the 1189th file... Progress:83.73239436619718%
# Processing the 1190th file... Progress:83.80281690140845%
# Processing the 1191th file... Progress:83.87323943661971%
# Processing the 1192th file... Progress:83.94366197183099%
# Processing the 1193th file... Progress:84.01408450704226%
# Processing the 1194th file... Progress:84.08450704225352%
# Processing the 1195th file... Progress:84.15492957746478%
# Processing the 1196th file... Progress:84.22535211267605%
# Processing the 1197th file... Progress:84.29577464788733%
# Processing the 1198th file... Progress:84.36619718309859%
# Processing the 1199th file... Progress:84.43661971830986%
# Processing the 1200th file... Progress:84.50704225352112%
# Processing the 1201th file... Progress:84.5774647887324%
# Processing the 1202th file... Progress:84.64788732394366%
# Processing the 1203th file... Progress:84.71830985915493%
# Processing the 1204th file... Progress:84.78873239436619%
# Processing the 1205th file... Progress:84.85915492957746%
# Processing the 1206th file... Progress:84.92957746478874%
# Processing the 1207th file... Progress:85.0%
# Processing the 1208th file... Progress:85.07042253521126%
# Processing the 1209th file... Progress:85.14084507042253%
# Processing the 1210th file... Progress:85.2112676056338%
# Processing the 1211th file... Progress:85.28169014084507%
# Processing the 1212th file... Progress:85.35211267605634%
# Processing the 1213th file... Progress:85.4225352112676%
# Processing the 1214th file... Progress:85.49295774647887%
# Processing the 1215th file... Progress:85.56338028169014%
# Processing the 1216th file... Progress:85.63380281690141%
# Processing the 1217th file... Progress:85.70422535211267%
# Processing the 1218th file... Progress:85.77464788732394%
# Processing the 1219th file... Progress:85.8450704225352%
# Processing the 1220th file... Progress:85.91549295774648%
# Processing the 1221th file... Progress:85.98591549295774%
# Processing the 1222th file... Progress:86.05633802816901%
# Processing the 1223th file... Progress:86.12676056338027%
# Processing the 1224th file... Progress:86.19718309859155%
# Processing the 1225th file... Progress:86.26760563380282%
# Processing the 1226th file... Progress:86.33802816901408%
# Processing the 1227th file... Progress:86.40845070422534%
# Processing the 1228th file... Progress:86.47887323943661%
# Processing the 1229th file... Progress:86.54929577464789%
# Processing the 1230th file... Progress:86.61971830985915%
# Processing the 1231th file... Progress:86.69014084507042%
# Processing the 1232th file... Progress:86.76056338028168%
# Processing the 1233th file... Progress:86.83098591549296%
# Processing the 1234th file... Progress:86.90140845070422%
# Processing the 1235th file... Progress:86.97183098591549%
# Processing the 1236th file... Progress:87.04225352112675%
# Processing the 1237th file... Progress:87.11267605633802%
# Processing the 1238th file... Progress:87.1830985915493%
# Processing the 1239th file... Progress:87.25352112676056%
# Processing the 1240th file... Progress:87.32394366197182%
# Processing the 1241th file... Progress:87.39436619718309%
# Processing the 1242th file... Progress:87.46478873239437%
# Processing the 1243th file... Progress:87.53521126760563%
# Processing the 1244th file... Progress:87.60563380281691%
# Processing the 1245th file... Progress:87.67605633802818%
# Processing the 1246th file... Progress:87.74647887323944%
# Processing the 1247th file... Progress:87.8169014084507%
# Processing the 1248th file... Progress:87.88732394366198%
# Processing the 1249th file... Progress:87.95774647887325%
# Processing the 1250th file... Progress:88.02816901408451%
# Processing the 1251th file... Progress:88.09859154929578%
# Processing the 1252th file... Progress:88.16901408450704%
# Processing the 1253th file... Progress:88.23943661971832%
# Processing the 1254th file... Progress:88.30985915492958%
# Processing the 1255th file... Progress:88.38028169014085%
# Processing the 1256th file... Progress:88.45070422535211%
# Processing the 1257th file... Progress:88.52112676056339%
# Processing the 1258th file... Progress:88.59154929577466%
# Processing the 1259th file... Progress:88.66197183098592%
# Processing the 1260th file... Progress:88.73239436619718%
# Processing the 1261th file... Progress:88.80281690140845%
# Processing the 1262th file... Progress:88.87323943661973%
# Processing the 1263th file... Progress:88.94366197183099%
# Processing the 1264th file... Progress:89.01408450704226%
# Processing the 1265th file... Progress:89.08450704225352%
# Processing the 1266th file... Progress:89.1549295774648%
# Processing the 1267th file... Progress:89.22535211267606%
# Processing the 1268th file... Progress:89.29577464788733%
# Processing the 1269th file... Progress:89.36619718309859%
# Processing the 1270th file... Progress:89.43661971830986%
# Processing the 1271th file... Progress:89.50704225352113%
# Processing the 1272th file... Progress:89.5774647887324%
# Processing the 1273th file... Progress:89.64788732394366%
# Processing the 1274th file... Progress:89.71830985915493%
# Processing the 1275th file... Progress:89.7887323943662%
# Processing the 1276th file... Progress:89.85915492957747%
# Processing the 1277th file... Progress:89.92957746478874%
# Processing the 1278th file... Progress:90.0%
# Processing the 1279th file... Progress:90.07042253521126%
# Processing the 1280th file... Progress:90.14084507042254%
# Processing the 1281th file... Progress:90.21126760563381%
# Processing the 1282th file... Progress:90.28169014084507%
# Processing the 1283th file... Progress:90.35211267605634%
# Processing the 1284th file... Progress:90.4225352112676%
# Processing the 1285th file... Progress:90.49295774647888%
# Processing the 1286th file... Progress:90.56338028169014%
# Processing the 1287th file... Progress:90.63380281690141%
# Processing the 1288th file... Progress:90.70422535211267%
# Processing the 1289th file... Progress:90.77464788732395%
# Processing the 1290th file... Progress:90.84507042253522%
# Processing the 1291th file... Progress:90.91549295774648%
# Processing the 1292th file... Progress:90.98591549295774%
# Processing the 1293th file... Progress:91.05633802816901%
# Processing the 1294th file... Progress:91.12676056338029%
# Processing the 1295th file... Progress:91.19718309859155%
# Processing the 1296th file... Progress:91.26760563380282%
# Processing the 1297th file... Progress:91.33802816901408%
# Processing the 1298th file... Progress:91.40845070422536%
# Processing the 1299th file... Progress:91.47887323943662%
# Processing the 1300th file... Progress:91.54929577464789%
# Processing the 1301th file... Progress:91.61971830985915%
# Processing the 1302th file... Progress:91.69014084507042%
# Processing the 1303th file... Progress:91.7605633802817%
# Processing the 1304th file... Progress:91.83098591549296%
# Processing the 1305th file... Progress:91.90140845070422%
# Processing the 1306th file... Progress:91.97183098591549%
# Processing the 1307th file... Progress:92.04225352112675%
# Processing the 1308th file... Progress:92.11267605633803%
# Processing the 1309th file... Progress:92.1830985915493%
# Processing the 1310th file... Progress:92.25352112676056%
# Processing the 1311th file... Progress:92.32394366197182%
# Processing the 1312th file... Progress:92.3943661971831%
# Processing the 1313th file... Progress:92.46478873239437%
# Processing the 1314th file... Progress:92.53521126760563%
# Processing the 1315th file... Progress:92.6056338028169%
# Processing the 1316th file... Progress:92.67605633802816%
# Processing the 1317th file... Progress:92.74647887323944%
# Processing the 1318th file... Progress:92.8169014084507%
# Processing the 1319th file... Progress:92.88732394366197%
# Processing the 1320th file... Progress:92.95774647887323%
# Processing the 1321th file... Progress:93.02816901408451%
# Processing the 1322th file... Progress:93.09859154929578%
# Processing the 1323th file... Progress:93.16901408450704%
# Processing the 1324th file... Progress:93.2394366197183%
# Processing the 1325th file... Progress:93.30985915492957%
# Processing the 1326th file... Progress:93.38028169014085%
# Processing the 1327th file... Progress:93.45070422535211%
# Processing the 1328th file... Progress:93.52112676056338%
# Processing the 1329th file... Progress:93.59154929577464%
# Processing the 1330th file... Progress:93.66197183098592%
# Processing the 1331th file... Progress:93.73239436619718%
# Processing the 1332th file... Progress:93.80281690140845%
# Processing the 1333th file... Progress:93.87323943661971%
# Processing the 1334th file... Progress:93.94366197183098%
# Processing the 1335th file... Progress:94.01408450704226%
# Processing the 1336th file... Progress:94.08450704225352%
# Processing the 1337th file... Progress:94.15492957746478%
# Processing the 1338th file... Progress:94.22535211267605%
# Processing the 1339th file... Progress:94.29577464788733%
# Processing the 1340th file... Progress:94.36619718309859%
# Processing the 1341th file... Progress:94.43661971830986%
# Processing the 1342th file... Progress:94.50704225352112%
# Processing the 1343th file... Progress:94.57746478873239%
# Processing the 1344th file... Progress:94.64788732394366%
# Processing the 1345th file... Progress:94.71830985915493%
# Processing the 1346th file... Progress:94.78873239436619%
# Processing the 1347th file... Progress:94.85915492957746%
# Processing the 1348th file... Progress:94.92957746478872%
# Processing the 1349th file... Progress:95.0%
# Processing the 1350th file... Progress:95.07042253521126%
# Processing the 1351th file... Progress:95.14084507042253%
# Processing the 1352th file... Progress:95.2112676056338%
# Processing the 1353th file... Progress:95.28169014084507%
# Processing the 1354th file... Progress:95.35211267605634%
# Processing the 1355th file... Progress:95.4225352112676%
# Processing the 1356th file... Progress:95.49295774647887%
# Processing the 1357th file... Progress:95.56338028169013%
# Processing the 1358th file... Progress:95.63380281690141%
# Processing the 1359th file... Progress:95.70422535211267%
# Processing the 1360th file... Progress:95.77464788732394%
# Processing the 1361th file... Progress:95.84507042253522%
# Processing the 1362th file... Progress:95.91549295774648%
# Processing the 1363th file... Progress:95.98591549295776%
# Processing the 1364th file... Progress:96.05633802816902%
# Processing the 1365th file... Progress:96.12676056338029%
# Processing the 1366th file... Progress:96.19718309859155%
# Processing the 1367th file... Progress:96.26760563380282%
# Processing the 1368th file... Progress:96.3380281690141%
# Processing the 1369th file... Progress:96.40845070422536%
# Processing the 1370th file... Progress:96.47887323943662%
# Processing the 1371th file... Progress:96.54929577464789%
# Processing the 1372th file... Progress:96.61971830985917%
# Processing the 1373th file... Progress:96.69014084507043%
# Processing the 1374th file... Progress:96.7605633802817%
# Processing the 1375th file... Progress:96.83098591549296%
# Processing the 1376th file... Progress:96.90140845070422%
# Processing the 1377th file... Progress:96.9718309859155%
# Processing the 1378th file... Progress:97.04225352112677%
# Processing the 1379th file... Progress:97.11267605633803%
# Processing the 1380th file... Progress:97.1830985915493%
# Processing the 1381th file... Progress:97.25352112676056%
# Processing the 1382th file... Progress:97.32394366197184%
# Processing the 1383th file... Progress:97.3943661971831%
# Processing the 1384th file... Progress:97.46478873239437%
# Processing the 1385th file... Progress:97.53521126760563%
# Processing the 1386th file... Progress:97.60563380281691%
# Processing the 1387th file... Progress:97.67605633802818%
# Processing the 1388th file... Progress:97.74647887323944%
# Processing the 1389th file... Progress:97.8169014084507%
# Processing the 1390th file... Progress:97.88732394366197%
# Processing the 1391th file... Progress:97.95774647887325%
# Processing the 1392th file... Progress:98.02816901408451%
# Processing the 1393th file... Progress:98.09859154929578%
# Processing the 1394th file... Progress:98.16901408450704%
# Processing the 1395th file... Progress:98.23943661971832%
# Processing the 1396th file... Progress:98.30985915492958%
# Processing the 1397th file... Progress:98.38028169014085%
# Processing the 1398th file... Progress:98.45070422535211%
# Processing the 1399th file... Progress:98.52112676056338%
# Processing the 1400th file... Progress:98.59154929577466%
# Processing the 1401th file... Progress:98.66197183098592%
# Processing the 1402th file... Progress:98.73239436619718%
# Processing the 1403th file... Progress:98.80281690140845%
# Processing the 1404th file... Progress:98.87323943661971%
# Processing the 1405th file... Progress:98.94366197183099%
# Processing the 1406th file... Progress:99.01408450704226%
# Processing the 1407th file... Progress:99.08450704225352%
# Processing the 1408th file... Progress:99.15492957746478%
# Processing the 1409th file... Progress:99.22535211267606%
# Processing the 1410th file... Progress:99.29577464788733%
# Processing the 1411th file... Progress:99.36619718309859%
# Processing the 1412th file... Progress:99.43661971830986%
# Processing the 1413th file... Progress:99.50704225352112%
# Processing the 1414th file... Progress:99.5774647887324%
# Processing the 1415th file... Progress:99.64788732394366%
# Processing the 1416th file... Progress:99.71830985915493%
# Processing the 1417th file... Progress:99.78873239436619%
# Processing the 1418th file... Progress:99.85915492957747%
# Processing the 1419th file... Progress:99.92957746478874%
# Processing the 1420th file... Progress:100.0%
# Processing the 1421th file... Progress:100.07042253521128%

# %% [markdown]
# # 2.词向量模型训练

# %% [markdown]
# ## __2.1 模型训练（须GPU）

# %%
# import modules & set up logging
import gensim, logging,os
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 
#sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two sentences
#model = gensim.models.Word2Vec(sentences, min_count=1)


class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname
 
    def __iter__(self):
        for fname in os.listdir(self.dirname):
            if fname[0]!='.':
                for line in open(os.path.join(self.dirname, fname)):
                    yield line.split()
                
sentences = MySentences('try/') # a memory-friendly iterator



model = gensim.models.Word2Vec(sentences,min_count=5)
model.save("word2vec.model")

# %% [markdown]
# ## __2.2 模型测试（参考网页https://radimrehurek.com/gensim/models/word2vec.html）
